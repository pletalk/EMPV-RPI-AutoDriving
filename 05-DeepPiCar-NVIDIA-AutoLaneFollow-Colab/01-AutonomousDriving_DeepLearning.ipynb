# %% [markdown]
# <a href="https://colab.research.google.com/github/pletalk/EMPV-RPI-AutoDriving/blob/master/05-DeepPiCar-NVIDIA-AutoLaneFollow-Colab/01-AutonomousDriving_DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepPiCar - OpenCV기반 자동 수집 주행 데이타 기반의 딥러닝 학습 및 주행(Deep Learning Driving)
# @2020-08-01/@pletalk
#
# OpenCV기반 자동 수집 주행 데이타(이미지)만으로 모델 학습하기
# * 수집된 데이타만으로 학습
#
# * 문서이력
#     * 2020-08-01 코드 점검 및 내용 보강
#     * 2020-06-22 데이타변형없이 주행데이타만으로 학습
#     * 2020-06-14 재검증(OK)
#     * 2020-05-24 코드추가하기(이미지로딩, 추가, 학습등)
#     * 2020-05-23 처음작성
#
# * [참고자료]
#     * [참조 소스코드(DeepPiCar)](https://github.com/dctian/DeepPiCar/blob/master/models/lane_navigation/code/end_to_end_lane_navigation.ipynb)
#     * [DeepPiCar — Part 5: Autonomous Lane Navigation via Deep Learning](https://towardsdatascience.com/deeppicar-part-5-lane-following-via-deep-learning-d93acdce6110)
#
# <img src="https://miro.medium.com/max/1374/1*p8JiHcvH-wpSxcCzz2r1Sw.jpeg"/>

# %% [markdown]
# ## [1] DeepPiCar Git코드 다운로드
# * 기본 다운로드 디렉토리는 /content/DeepPiCar 디렉토리에 저장

# %%
! git clone https://github.com/dctian/DeepPiCar.git
# Out:
# fatal: destination path 'DeepPiCar' already exists and is not an empty directory.

# %%
! pwd
! cd DeepPiCar
# Out:
# /content

# %% [markdown]
# ## [2] 라이브러리 로딩하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import logging
import math

import os
import random
import fnmatch
import datetime
import pickle

# data processing
import numpy as np
np.set_printoptions(formatter={'float_kind':lambda x: "%.4f" % x})

import pandas as pd
pd.set_option('display.width', 300)
pd.set_option('display.float_format', '{:,.4f}'.format)
pd.set_option('display.max_colwidth', 200)

# tensorflow
import tensorflow as tf
import keras
from keras.models import Sequential  # V2 is tensorflow.keras.xxxx, V1 is keras.xxx
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense
from keras.optimizers import Adam
from keras.models import load_model
print( f'tf.__version__: {tf.__version__}' )
print( f'keras.__version__: {keras.__version__}' )

# sklearn
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# imaging
from imgaug import augmenters as img_aug
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image
# Out:
# Using TensorFlow backend.
# tf.__version__: 2.2.0
# keras.__version__: 2.3.1

# %% [markdown]
# ## [3] OpenCV기반 주행선탐지를 위한 이미지 가져오기
#     * directory에 주행을 캡쳐한 이미지들이 있음
#     * 로딩을 위한 코드 작성

# %% [markdown]
# ### 1> 학습할 동영상의 프레임별 이미지 파일 로딩하기

# %%
# 데이타를 가져올 디렉토리 설정하기
# 확장자 *.png를 가지는 파일들을 확인할 것
# 파일명의 포맷 -> 이름_순서_각도.png
data_dir = '/content/DeepPiCar/models/lane_navigation/data/images'

# %% [markdown]
# ### 2> 이미지저장 디렉토리에서 이미지파일 파일 읽어서 분류하기 (경로, 각도)

# %%
file_list = os.listdir(data_dir)
image_paths = []
steering_angles = []
pattern = "*.png"
for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(data_dir,filename))
        angle = int(filename[-7:-4])  # 092 part of video01_143_092.png is the angle. 90 is go straight
        steering_angles.append(angle)

# %% [markdown]
# ### 3> 파일경로와 각도 리스트 확인하기

# %%
image_paths[0:3]
# Out:
# ['/content/DeepPiCar/models/lane_navigation/data/images/video01_011_062.png',
#  '/content/DeepPiCar/models/lane_navigation/data/images/video01_204_077.png',
#  '/content/DeepPiCar/models/lane_navigation/data/images/video01_049_065.png']

# %%
steering_angles[0:3]
# Out:
# [62, 77, 65]

# %%
df = pd.DataFrame()
df['ImagePath'] = image_paths
df['Angle'] = steering_angles

# %%
# 주행각도에 대한 분포
num_of_bins = 25
samples_per_bin = 400
hist, bins = np.histogram(df['Angle'], num_of_bins)

fig, axes = plt.subplots(1,1, figsize=(12,4))
axes.hist(df['Angle'], bins=num_of_bins, width=1, color='blue')
# Out:
# (array([1.0000, 1.0000, 8.0000, 4.0000, 5.0000, 11.0000, 6.0000, 7.0000,
#         26.0000, 2.0000, 10.0000, 21.0000, 18.0000, 23.0000, 15.0000,
#         21.0000, 12.0000, 10.0000, 2.0000, 5.0000, 2.0000, 1.0000, 3.0000,
#         2.0000, 3.0000]),
#  array([44.0000, 46.3600, 48.7200, 51.0800, 53.4400, 55.8000, 58.1600,
#         60.5200, 62.8800, 65.2400, 67.6000, 69.9600, 72.3200, 74.6800,
#         77.0400, 79.4000, 81.7600, 84.1200, 86.4800, 88.8400, 91.2000,
#         93.5600, 95.9200, 98.2800, 100.6400, 103.0000]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# ## [4] 학습데이타와 테스트 데이타 나누기

# %% [markdown]
# ### 1> train_test_split()를 활용하여 나누기 (비율기반)

# %%
X_train, X_valid, y_train, y_valid = train_test_split( image_paths, steering_angles, test_size=0.2)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))
# Out:
# Training data: 175
# Validation data: 44

# %%
# plot the distributions of train and valid, make sure they are consistent
fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].hist(y_train, bins=num_of_bins, width=1, color='blue')
axes[0].set_title('Training Data')
axes[1].hist(y_valid, bins=num_of_bins, width=1, color='red')
axes[1].set_title('Validation Data')
# Out:
# Text(0.5, 1.0, 'Validation Data')

# %% [markdown]
# ## [5] 이미지 로딩 및 처리 함수들

# %% [markdown]
# ### 1> 이미지 출력하기

# %%
def show_image(image):
    plt.figure(figsize=(8,6))
    plt.imshow(image)

def show_compare_images(src_image, tgt_image):
    nrow=1
    ncol=2
    fig, axes = plt.subplots(nrow, ncol, figsize=(12, 6))
    fig.tight_layout()
    axes[0].imshow(src_image)
    axes[1].imshow(tgt_image)

# %% [markdown]
# ### 2> 이미지 로딩하기

# %%
def load_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %% [markdown]
# ### 3> 이미지 로딩 및 출력 테스팅

# %%
test_sample_index = 0

rgb_image = load_image(X_train[test_sample_index])
steering_angle = y_train[test_sample_index]
print("origin_image_file=",X_train[test_sample_index])
print("origin_steering_angle=",steering_angle)
show_image(rgb_image)
# Out:
# origin_image_file= /content/DeepPiCar/models/lane_navigation/data/images/video01_016_056.png
# origin_steering_angle= 56

# %%
rgb_image.shape
# Out:
# (240, 320, 3)

# %% [markdown]
# ## [6] 이미지 전처리하기(preprocessing)
# * NVIDIA모델의 입력 크기로 변경

# %% [markdown]
# ### 1> 이미지 전처의 단계별 수행과정 이해
# * 이미지의 크기 변경 (높이를 1/2로 변경)

# %%
# 이미지의 rgb 차원의 slice값으로 이미지 크기를 변경
height, _, _ = rgb_image.shape
resized_rgb_image = rgb_image[int(height/2):,:,:]

# %%
rgb_image.shape
# Out:
# (240, 320, 3)

# %%
resized_rgb_image.shape
# Out:
# (120, 320, 3)

# %%
show_compare_images(rgb_image, resized_rgb_image)

# %% [markdown]
# ### 2> 이미지의 형식변경 (RGB -> YUV)

# %%
resized_yuv_image = cv2.cvtColor(resized_rgb_image, cv2.COLOR_RGB2YUV)

# %%
show_compare_images(resized_rgb_image, resized_yuv_image)

# %% [markdown]
# ### 3> 가우시언블러링 처리(kernel size= 3)

# %%
resized_yuv_blurred_image = cv2.GaussianBlur(resized_yuv_image, (3,3), 0)

# %%
show_compare_images(resized_yuv_image, resized_yuv_blurred_image)

# %% [markdown]
# ### 4> 이미지 크기 변경 (340x320 -> 66x200)

# %%
nvidia_input_image = cv2.resize(resized_yuv_blurred_image, (200,66))

# %%
nvidia_input_image.shape
# Out:
# (66, 200, 3)

# %%
show_compare_images(resized_yuv_image, nvidia_input_image)

# %% [markdown]
# ### 5> 위의 처리과정의 통합 함수 (img_preprocess)

# %%
# 1) 이미지의 포맷을 RGB2YUV로 변경
# 2) GuassianBlur처리를 수행
# 3) 프레임이미지 크기 변경 : 240x320 ->66x200

def img_preprocess(image):
    height, _, _ = image.shape
    image = image[int(height/2):,:,:]  
    image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)  
    image = cv2.GaussianBlur(image, (3,3), 0)
    image = cv2.resize(image, (200,66)) 
    image = image / 255 
    return image

# %%
prep_image = img_preprocess(rgb_image)

# %%
prep_image.shape
# Out:
# (66, 200, 3)

# %%
show_image(prep_image)

# %% [markdown]
# ## [7] NVIDIA 모델 정의하기

# %% [markdown]
# ### 1> NVIDIA Deep Learning 모델 정의하기

# %%
def nvidia_model():
    model = Sequential(name='Nvidia_Model')
    
    # elu=Expenential Linear Unit, similar to leaky Relu
    # skipping 1st hiddel layer (nomralization layer), as we have normalized the data
    
    # Convolution Layers
    model.add(Conv2D(24, (5, 5), strides=(2, 2), input_shape=(66, 200, 3), activation='elu')) 
    model.add(Conv2D(36, (5, 5), strides=(2, 2), activation='elu')) 
    model.add(Conv2D(48, (5, 5), strides=(2, 2), activation='elu')) 
    model.add(Conv2D(64, (3, 3), activation='elu')) 
    model.add(Dropout(0.2)) # not in original model. added for more robustness
    model.add(Conv2D(64, (3, 3), activation='elu')) 
    
    # Fully Connected Layers
    model.add(Flatten())
    model.add(Dropout(0.2)) # not in original model. added for more robustness
    model.add(Dense(100, activation='elu'))
    model.add(Dense(50, activation='elu'))
    model.add(Dense(10, activation='elu'))
    
    # output layer: turn angle (from 45-135, 90 is straight, <90 turn left, >90 turn right)
    model.add(Dense(1)) 
    
    # since this is a regression problem not classification problem,
    # we use MSE (Mean Squared Error) as loss function
    optimizer = Adam(lr=1e-3) # lr is learning rate
    model.compile(loss='mse', optimizer=optimizer)
    
    return model

# %% [markdown]
# ### 2> 모델생성하기

# %%
model = nvidia_model()
print(model.summary())
# check at we will have 252,219 trainable parameters
# Out:
# Model: "Nvidia_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 20, 64)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               115300
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 252,219
# Trainable params: 252,219
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## [8] NVIDIA 주행 모델 학습하기

# %% [markdown]
# ### 1> Tensorboard 설정하기

# %%
model_output_dir = '/content/DeepPiCar/models/lane_navigation'
! mkdir '/content/DeepPiCar/models/lane_navigation/logs'
# Out:
# mkdir: cannot create directory ‘/content/DeepPiCar/models/lane_navigation/logs’: File exists

# %%
# tensorflow의 수행 로그 저장 디렉토리 설정하기
log_dir_root = f'{model_output_dir}/logs/'
log_dir_root
# Out:
# '/content/DeepPiCar/models/lane_navigation/logs/'

# %% [markdown]
# ### 2> 학습 및 테스트 데이타 만들기

# %%
#
# 학습/테스트 이미지 파일명의 리스트를 입력 받아서 numpy.array()로 변환
#

def merge_images(filepath_list):
    merge_list = []
    for fname in filepath_list:
        # 원래 이미지를 로딩
        trgb_image = load_image(fname)

        # 전처리를 수행
        prep_trgb_image = img_preprocess(trgb_image)
        merge_list.append(prep_trgb_image)
    return np.array(merge_list)

# %%
tX_train = merge_images(X_train)
tX_train.shape
# Out:
# (175, 66, 200, 3)

# %%
tX_valid = merge_images(X_valid)
tX_valid.shape
# Out:
# (44, 66, 200, 3)

# %% [markdown]
# ### 3> NVIDIA주행 학습하기
#
# * Keara모델 기반의 CNN학습과 동일하게 진행

# %%
batch_size = 8
epochs = 100

# %%
history = model.fit(tX_train,y_train,
                    batch_size = batch_size,
                    epochs=epochs,
                    validation_data=(tX_valid, y_valid),
                    verbose=1)
# Out:
# Train on 175 samples, validate on 44 samples
# Epoch 1/100
# 175/175 [==============================] - 3s 17ms/step - loss: 1412.6440 - val_loss: 123.0986
# Epoch 2/100
# 175/175 [==============================] - 0s 965us/step - loss: 214.3723 - val_loss: 121.4583
# Epoch 3/100
# 175/175 [==============================] - 0s 980us/step - loss: 167.1319 - val_loss: 185.2803
# Epoch 4/100
# 175/175 [==============================] - 0s 938us/step - loss: 193.7647 - val_loss: 103.1986
# Epoch 5/100
# 175/175 [==============================] - 0s 926us/step - loss: 162.3434 - val_loss: 192.8440
# Epoch 6/100
# 175/175 [==============================] - 0s 949us/step - loss: 210.3583 - val_loss: 109.5022
# Epoch 7/100
# 175/175 [==============================] - 0s 995us/step - loss: 216.8628 - val_loss: 101.9997
# Epoch 8/100
# 175/175 [==============================] - 0s 959us/step - loss: 136.5850 - val_loss: 103.2205
# Epoch 9/100
# 175/175 [==============================] - 0s 972us/step - loss: 159.5671 - val_loss: 145.2652
# Epoch 10/100
# 175/175 [==============================] - 0s 922us/step - loss: 147.6208 - val_loss: 111.5635
# Epoch 11/100
# 175/175 [==============================] - 0s 926us/step - loss: 132.6901 - val_loss: 85.0513
# Epoch 12/100
# 175/175 [==============================] - 0s 984us/step - loss: 134.7583 - val_loss: 76.9436
# Epoch 13/100
# 175/175 [==============================] - 0s 1ms/step - loss: 115.3697 - val_loss: 90.0023
# Epoch 14/100
# 175/175 [==============================] - 0s 1ms/step - loss: 97.3819 - val_loss: 89.1978
# Epoch 15/100
# 175/175 [==============================] - 0s 1ms/step - loss: 99.6229 - val_loss: 98.0454
# Epoch 16/100
# 175/175 [==============================] - 0s 1ms/step - loss: 84.8783 - val_loss: 60.4441
# Epoch 17/100
# 175/175 [==============================] - 0s 1ms/step - loss: 79.9399 - val_loss: 97.8373
# Epoch 18/100
# 175/175 [==============================] - 0s 975us/step - loss: 89.6565 - val_loss: 77.8886
# Epoch 19/100
# 175/175 [==============================] - 0s 1ms/step - loss: 84.8557 - val_loss: 61.4996
# Epoch 20/100
# 175/175 [==============================] - 0s 1ms/step - loss: 63.0140 - val_loss: 54.2974
# Epoch 21/100
# 175/175 [==============================] - 0s 982us/step - loss: 51.0563 - val_loss: 74.4983
# Epoch 22/100
# 175/175 [==============================] - 0s 965us/step - loss: 52.6915 - val_loss: 79.3385
# Epoch 23/100
# 175/175 [==============================] - 0s 993us/step - loss: 60.6461 - val_loss: 51.4467
# Epoch 24/100
# 175/175 [==============================] - 0s 982us/step - loss: 61.5264 - val_loss: 170.7633
# Epoch 25/100
# 175/175 [==============================] - 0s 1ms/step - loss: 71.2268 - val_loss: 41.8323
# Epoch 26/100
# 175/175 [==============================] - 0s 1ms/step - loss: 47.2043 - val_loss: 47.9873
# Epoch 27/100
# 175/175 [==============================] - 0s 987us/step - loss: 40.1270 - val_loss: 25.6951
# Epoch 28/100
# 175/175 [==============================] - 0s 999us/step - loss: 44.1776 - val_loss: 35.0483
# Epoch 29/100
# 175/175 [==============================] - 0s 1ms/step - loss: 25.3779 - val_loss: 42.4063
# Epoch 30/100
# 175/175 [==============================] - 0s 990us/step - loss: 27.1731 - val_loss: 39.9980
# Epoch 31/100
# 175/175 [==============================] - 0s 1ms/step - loss: 32.1413 - val_loss: 15.3235
# Epoch 32/100
# 175/175 [==============================] - 0s 1ms/step - loss: 24.2233 - val_loss: 13.7419
# Epoch 33/100
# 175/175 [==============================] - 0s 977us/step - loss: 21.4701 - val_loss: 16.4208
# Epoch 34/100
# 175/175 [==============================] - 0s 978us/step - loss: 22.1146 - val_loss: 11.4267
# Epoch 35/100
# 175/175 [==============================] - 0s 996us/step - loss: 24.9158 - val_loss: 26.5624
# Epoch 36/100
# 175/175 [==============================] - 0s 1ms/step - loss: 25.0152 - val_loss: 21.6399
# Epoch 37/100
# 175/175 [==============================] - 0s 1ms/step - loss: 30.5409 - val_loss: 32.3165
# Epoch 38/100
# 175/175 [==============================] - 0s 1ms/step - loss: 25.8572 - val_loss: 13.9567
# Epoch 39/100
# 175/175 [==============================] - 0s 974us/step - loss: 19.5253 - val_loss: 11.1530
# Epoch 40/100
# 175/175 [==============================] - 0s 997us/step - loss: 18.8414 - val_loss: 13.7213
# Epoch 41/100
# 175/175 [==============================] - 0s 1ms/step - loss: 19.3762 - val_loss: 19.7826
# Epoch 42/100
# 175/175 [==============================] - 0s 1ms/step - loss: 17.2522 - val_loss: 9.8276
# Epoch 43/100
# 175/175 [==============================] - 0s 1ms/step - loss: 14.0967 - val_loss: 9.8070
# Epoch 44/100
# 175/175 [==============================] - 0s 1ms/step - loss: 17.9588 - val_loss: 20.1152
# Epoch 45/100
# 175/175 [==============================] - 0s 984us/step - loss: 20.7992 - val_loss: 25.3093
# Epoch 46/100
# 175/175 [==============================] - 0s 1ms/step - loss: 18.8803 - val_loss: 16.7793
# Epoch 47/100
# 175/175 [==============================] - 0s 988us/step - loss: 17.6409 - val_loss: 10.7692
# Epoch 48/100
# 175/175 [==============================] - 0s 1ms/step - loss: 16.6648 - val_loss: 7.8320
# Epoch 49/100
# 175/175 [==============================] - 0s 1ms/step - loss: 17.9394 - val_loss: 10.1337
# Epoch 50/100
# 175/175 [==============================] - 0s 1000us/step - loss: 15.2904 - val_loss: 15.3635
# Epoch 51/100
# 175/175 [==============================] - 0s 1ms/step - loss: 19.3411 - val_loss: 9.5665
# Epoch 52/100
# 175/175 [==============================] - 0s 983us/step - loss: 19.2070 - val_loss: 17.7074
# Epoch 53/100
# 175/175 [==============================] - 0s 1ms/step - loss: 15.0363 - val_loss: 7.7284
# Epoch 54/100
# 175/175 [==============================] - 0s 1ms/step - loss: 13.7073 - val_loss: 9.3314
# Epoch 55/100
# 175/175 [==============================] - 0s 1ms/step - loss: 12.6754 - val_loss: 6.1626
# Epoch 56/100
# 175/175 [==============================] - 0s 979us/step - loss: 11.9466 - val_loss: 12.8146
# Epoch 57/100
# 175/175 [==============================] - 0s 1ms/step - loss: 13.1582 - val_loss: 14.7410
# Epoch 58/100
# 175/175 [==============================] - 0s 977us/step - loss: 11.4711 - val_loss: 6.8764
# Epoch 59/100
# 175/175 [==============================] - 0s 1ms/step - loss: 15.0363 - val_loss: 7.6780
# Epoch 60/100
# 175/175 [==============================] - 0s 1ms/step - loss: 13.1058 - val_loss: 6.6242
# Epoch 61/100
# 175/175 [==============================] - 0s 987us/step - loss: 12.3228 - val_loss: 7.6268
# Epoch 62/100
# 175/175 [==============================] - 0s 983us/step - loss: 14.2363 - val_loss: 8.1587
# Epoch 63/100
# 175/175 [==============================] - 0s 991us/step - loss: 12.7952 - val_loss: 10.0278
# Epoch 64/100
# 175/175 [==============================] - 0s 963us/step - loss: 11.9479 - val_loss: 7.3194
# Epoch 65/100
# 175/175 [==============================] - 0s 1ms/step - loss: 15.9244 - val_loss: 9.2213
# Epoch 66/100
# 175/175 [==============================] - 0s 1ms/step - loss: 12.7419 - val_loss: 9.2992
# Epoch 67/100
# 175/175 [==============================] - 0s 964us/step - loss: 11.3842 - val_loss: 8.7351
# Epoch 68/100
# 175/175 [==============================] - 0s 1ms/step - loss: 11.3427 - val_loss: 8.7097
# Epoch 69/100
# 175/175 [==============================] - 0s 992us/step - loss: 11.7441 - val_loss: 19.8490
# Epoch 70/100
# 175/175 [==============================] - 0s 1ms/step - loss: 17.0084 - val_loss: 7.9640
# Epoch 71/100
# 175/175 [==============================] - 0s 1ms/step - loss: 10.8661 - val_loss: 7.9695
# Epoch 72/100
# 175/175 [==============================] - 0s 1ms/step - loss: 11.1904 - val_loss: 10.2753
# Epoch 73/100
# 175/175 [==============================] - 0s 994us/step - loss: 12.0721 - val_loss: 7.4473
# Epoch 74/100
# 175/175 [==============================] - 0s 1ms/step - loss: 12.6708 - val_loss: 8.5544
# Epoch 75/100
# 175/175 [==============================] - 0s 1ms/step - loss: 9.9473 - val_loss: 10.0157
# Epoch 76/100
# 175/175 [==============================] - 0s 1ms/step - loss: 10.8864 - val_loss: 6.9949
# Epoch 77/100
# 175/175 [==============================] - 0s 1ms/step - loss: 11.4091 - val_loss: 7.7680
# Epoch 78/100
# 175/175 [==============================] - 0s 985us/step - loss: 11.2717 - val_loss: 10.5801
# Epoch 79/100
# 175/175 [==============================] - 0s 1ms/step - loss: 11.3006 - val_loss: 15.1503
# Epoch 80/100
# 175/175 [==============================] - 0s 986us/step - loss: 17.8980 - val_loss: 13.2274
# Epoch 81/100
# 175/175 [==============================] - 0s 994us/step - loss: 11.8591 - val_loss: 8.5362
# Epoch 82/100
# 175/175 [==============================] - 0s 1ms/step - loss: 12.2566 - val_loss: 9.3973
# Epoch 83/100
# 175/175 [==============================] - 0s 989us/step - loss: 9.2652 - val_loss: 9.3862
# Epoch 84/100
# 175/175 [==============================] - 0s 1ms/step - loss: 12.3249 - val_loss: 7.8623
# Epoch 85/100
# 175/175 [==============================] - 0s 983us/step - loss: 14.4292 - val_loss: 18.9782
# Epoch 86/100
# 175/175 [==============================] - 0s 1ms/step - loss: 13.3103 - val_loss: 8.3724
# Epoch 87/100
# 175/175 [==============================] - 0s 993us/step - loss: 12.2392 - val_loss: 9.7703
# Epoch 88/100
# 175/175 [==============================] - 0s 1ms/step - loss: 13.9629 - val_loss: 10.9519
# Epoch 89/100
# 175/175 [==============================] - 0s 1ms/step - loss: 10.8109 - val_loss: 14.5337
# Epoch 90/100
# 175/175 [==============================] - 0s 1ms/step - loss: 11.8926 - val_loss: 9.3520
# Epoch 91/100
# 175/175 [==============================] - 0s 989us/step - loss: 11.1193 - val_loss: 11.5144
# Epoch 92/100
# 175/175 [==============================] - 0s 1ms/step - loss: 10.7294 - val_loss: 8.5938
# Epoch 93/100
# 175/175 [==============================] - 0s 1ms/step - loss: 14.7348 - val_loss: 14.5420
# Epoch 94/100
# 175/175 [==============================] - 0s 1ms/step - loss: 15.1601 - val_loss: 12.2140
# Epoch 95/100
# 175/175 [==============================] - 0s 981us/step - loss: 11.0386 - val_loss: 8.1460
# Epoch 96/100
# 175/175 [==============================] - 0s 1ms/step - loss: 10.6478 - val_loss: 10.2742
# Epoch 97/100
# 175/175 [==============================] - 0s 1ms/step - loss: 9.7231 - val_loss: 8.2715
# Epoch 98/100
# 175/175 [==============================] - 0s 996us/step - loss: 8.5067 - val_loss: 6.1467
# Epoch 99/100
# 175/175 [==============================] - 0s 1ms/step - loss: 8.5572 - val_loss: 7.2900
# Epoch 100/100
# 175/175 [==============================] - 0s 1ms/step - loss: 12.9529 - val_loss: 11.0318

# %% [markdown]
# ### 3> 학습모델 저장하기

# %%
# epoch를 반복하면서 저장된 모델값은 _check.h5로 저장 
# 최종적인 학습모델의 값을 저장 

model.save(os.path.join(model_output_dir,'std_lane_navigation_final.h5'))

# %%
print("model_output_dir=",model_output_dir)
# Out:
# model_output_dir= /content/DeepPiCar/models/lane_navigation

# %% [markdown]
# ## [10] 검증하기(validation)

# %% [markdown]
# ### 1> 학습 및 검증오류 확인하기(그래프)

# %%
history.history
# Out:
# {'loss': [1412.6439862932477,
#   214.37230970110213,
#   167.1319257899693,
#   193.7647461809431,
#   162.34344063895088,
#   210.35828639439174,
#   216.8628275844029,
#   136.5849674333845,
#   159.56707380022323,
#   147.62083674839565,
#   132.69009957449776,
#   134.75827122279577,
#   115.36969408307756,
#   97.38187905447823,
#   99.62289956229074,
#   84.87834250313895,
#   79.93991470336914,
#   89.65648060389927,
#   84.85569117954799,
#   63.01400442940848,
#   51.05630767822266,
#   52.69154482160296,
#   60.64609946114676,
#   61.52644429888044,
#   71.22676110403879,
#   47.20430901663644,
#   40.1270193699428,
#   44.17760981968471,
#   25.377916330610002,
#   27.173077109200612,
#   32.14129636492048,
#   24.223285413469586,
#   21.47012878417969,
#   22.114605691092354,
#   24.915813751220703,
#   25.015192762102398,
#   30.540946066720146,
#   25.857246578761508,
#   19.525327385493686,
#   18.84142897469657,
#   19.376241258893693,
#   17.252154824393138,
#   14.096666423252652,
#   17.95882658822196,
#   20.7991538974217,
#   18.88032191140311,
#   17.640913091387066,
#   16.664752088274273,
#   17.939438814435686,
#   15.290420164380755,
#   19.34107164655413,
#   19.207037309919084,
#   15.03633371080671,
#   13.707331488473075,
#   12.67538323538644,
#   11.94655207497733,
#   13.158150209699357,
#   11.47108850479126,
#   15.036255738394601,
#   13.105777222769602,
#   12.32281102861677,
#   14.236311329432896,
#   12.795213448660714,
#   11.947853652409146,
#   15.92440060206822,
#   12.74194592339652,
#   11.38420194353376,
#   11.34269841330392,
#   11.744108123779297,
#   17.008356415884837,
#   10.866080850873674,
#   11.190387687683106,
#   12.072125124250139,
#   12.670799255371094,
#   9.947288564954485,
#   10.886419890267508,
#   11.40910301208496,
#   11.271722447531564,
#   11.300576858520508,
#   17.898040226527623,
#   11.859052568163191,
#   12.256616445268904,
#   9.265178560529437,
#   12.324923139299665,
#   14.429242624555314,
#   13.310349085671561,
#   12.23922148023333,
#   13.962869894845145,
#   10.81087512425014,
#   11.892564043317522,
#   11.119257670811244,
#   10.7294378389631,
#   14.734769565037318,
#   15.160089819771903,
#   11.038560583932059,
#   10.647754977090019,
#   9.723143296922956,
#   8.506739082336425,
#   8.557192143031529,
#   12.952861960274832],
#  'val_loss': [123.09864807128906,
#   121.45828801935369,
#   185.28031782670453,
#   103.19864307750355,
#   192.84403852982953,
#   109.50217923251066,
#   101.99967540394177,
#   103.22050545432351,
#   145.26516168767756,
#   111.56348211115056,
#   85.05130074240945,
#   76.9435639814897,
#   90.00233459472656,
#   89.19781286066228,
#   98.0454268022017,
#   60.444122314453125,
#   97.83733992143111,
#   77.88864759965377,
#   61.49956685846502,
#   54.297448591752485,
#   74.49825633655895,
#   79.3384711525657,
#   51.44666914506392,
#   170.76333756880328,
#   41.83229351043701,
#   47.987300872802734,
#   25.695110321044922,
#   35.04831279407848,
#   42.40626109730113,
#   39.998003872958094,
#   15.323522914539684,
#   13.741853713989258,
#   16.420841390436347,
#   11.426694609902121,
#   26.56240324540572,
#   21.639943556352094,
#   32.31645063920455,
#   13.956671281294389,
#   11.15300213206898,
#   13.721315557306463,
#   19.782555666836824,
#   9.827572909268467,
#   9.806966662406921,
#   20.115205764770508,
#   25.30928577076305,
#   16.779294447465375,
#   10.769234397194602,
#   7.832047809254039,
#   10.133687376976013,
#   15.363457766446201,
#   9.566452676599676,
#   17.707414150238037,
#   7.728379292921587,
#   9.331382924860174,
#   6.162596182389692,
#   12.81463891809637,
#   14.741044391285289,
#   6.8763511614366015,
#   7.6780337420376865,
#   6.624195879155939,
#   7.626800190318715,
#   8.158721826293252,
#   10.027826244180853,
#   7.31937651200728,
#   9.221327434886586,
#   9.299224333329635,
#   8.735083254900845,
#   8.709693952040238,
#   19.84897145357999,
#   7.9639926823702725,
#   7.969488967548717,
#   10.275329676541416,
#   7.447323826226321,
#   8.554392792961814,
#   10.015748240730979,
#   6.994930069554936,
#   7.768047506159002,
#   10.58006139235063,
#   15.15026803450151,
#   13.22736050865867,
#   8.536173798821189,
#   9.397304491563277,
#   9.386150100014426,
#   7.862295800989324,
#   18.97821790521795,
#   8.372411294416947,
#   9.770290808244185,
#   10.951940016313033,
#   14.533670165322043,
#   9.351952466097744,
#   11.51440143585205,
#   8.593769962137396,
#   14.54195854880593,
#   12.213967756791549,
#   8.1460204557939,
#   10.274236115542324,
#   8.271529761227695,
#   6.146677429025823,
#   7.290017604827881,
#   11.031811302358454]}

# %%
# 학습데이타의 손실/epoch
history.history['loss']
# Out:
# [1412.6439862932477,
#  214.37230970110213,
#  167.1319257899693,
#  193.7647461809431,
#  162.34344063895088,
#  210.35828639439174,
#  216.8628275844029,
#  136.5849674333845,
#  159.56707380022323,
#  147.62083674839565,
#  132.69009957449776,
#  134.75827122279577,
#  115.36969408307756,
#  97.38187905447823,
#  99.62289956229074,
#  84.87834250313895,
#  79.93991470336914,
#  89.65648060389927,
#  84.85569117954799,
#  63.01400442940848,
#  51.05630767822266,
#  52.69154482160296,
#  60.64609946114676,
#  61.52644429888044,
#  71.22676110403879,
#  47.20430901663644,
#  40.1270193699428,
#  44.17760981968471,
#  25.377916330610002,
#  27.173077109200612,
#  32.14129636492048,
#  24.223285413469586,
#  21.47012878417969,
#  22.114605691092354,
#  24.915813751220703,
#  25.015192762102398,
#  30.540946066720146,
#  25.857246578761508,
#  19.525327385493686,
#  18.84142897469657,
#  19.376241258893693,
#  17.252154824393138,
#  14.096666423252652,
#  17.95882658822196,
#  20.7991538974217,
#  18.88032191140311,
#  17.640913091387066,
#  16.664752088274273,
#  17.939438814435686,
#  15.290420164380755,
#  19.34107164655413,
#  19.207037309919084,
#  15.03633371080671,
#  13.707331488473075,
#  12.67538323538644,
#  11.94655207497733,
#  13.158150209699357,
#  11.47108850479126,
#  15.036255738394601,
#  13.105777222769602,
#  12.32281102861677,
#  14.236311329432896,
#  12.795213448660714,
#  11.947853652409146,
#  15.92440060206822,
#  12.74194592339652,
#  11.38420194353376,
#  11.34269841330392,
#  11.744108123779297,
#  17.008356415884837,
#  10.866080850873674,
#  11.190387687683106,
#  12.072125124250139,
#  12.670799255371094,
#  9.947288564954485,
#  10.886419890267508,
#  11.40910301208496,
#  11.271722447531564,
#  11.300576858520508,
#  17.898040226527623,
#  11.859052568163191,
#  12.256616445268904,
#  9.265178560529437,
#  12.324923139299665,
#  14.429242624555314,
#  13.310349085671561,
#  12.23922148023333,
#  13.962869894845145,
#  10.81087512425014,
#  11.892564043317522,
#  11.119257670811244,
#  10.7294378389631,
#  14.734769565037318,
#  15.160089819771903,
#  11.038560583932059,
#  10.647754977090019,
#  9.723143296922956,
#  8.506739082336425,
#  8.557192143031529,
#  12.952861960274832]

# %%
plt.plot(history.history['loss'],color='blue')
plt.plot(history.history['val_loss'],color='red')
plt.legend(["training loss", "validation loss"])

# %% [markdown]
# ### 2> 학습모델 로딩 및 검증결과 출력하기

# %%
from sklearn.metrics import mean_squared_error, r2_score

def summarize_prediction(Y_true, Y_pred):
    
    mse = mean_squared_error(Y_true, Y_pred)
    r_squared = r2_score(Y_true, Y_pred)
    
    print(f'mse       = {mse:.2}')
    print(f'r_squared = {r_squared:.2%}')
    print()
    
def predict_and_summarize(X, Y):
    model = load_model(f'{model_output_dir}/std_lane_navigation_final.h5')
    Y_pred = model.predict(X)
    summarize_prediction(Y, Y_pred)
    return Y_pred

# %% [markdown]
# ### 3> 검증결과 출력하기

# %%
y_pred = predict_and_summarize(tX_valid, y_valid)
# Out:
# mse       = 1.1e+01
# r_squared = 89.86%

# %% [markdown]
# ### 4> 검증결과 이미지출력하기

# %%
n_tests_show = 5
fig, axes = plt.subplots(n_tests_show, 1, figsize=(10, 4 * n_tests_show))
for i in range(n_tests_show):
    axes[i].imshow(tX_valid[i+5])
    axes[i].set_title(f"actual angle={y_valid[i]}, predicted angle={int(y_pred[i])}, diff = {int(y_pred[i])-y_valid[i]}")

# %% [markdown]
# ## [11] 학슴모델 로딩 및 파라미터 확인하기

# %%
from tensorflow import keras

model_path = os.path.join(model_output_dir,'std_lane_navigation_final.h5')
print(model_path)
# Out:
# /content/DeepPiCar/models/lane_navigation/std_lane_navigation_final.h5

# %%
# keras model 로딩하기
loaded_model = keras.models.load_model(model_path)

# %%
#dir(loaded_model)

# %%
to_json = loaded_model.to_json()
print(to_json)
# Out:
# {"class_name": "Sequential", "config": {"name": "Nvidia_Model", "layers": [{"class_name": "Conv2D", "config": {"name": "conv2d_1", "trainable": true, "batch_input_shape": [null, 66, 200, 3], "dtype": "float32", "filters": 24, "kernel_size": [5, 5], "strides": [2, 2], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "elu", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_avg", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Conv2D", "config": {"name": "conv2d_2", "trainable": true, "dtype": "float32", "filters": 36, "kernel_size": [5, 5], "strides": [2, 2], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "elu", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_avg", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Conv2D", "config": {"name": "conv2d_3", "trainable": true, "dtype": "float32", "filters": 48, "kernel_size": [5, 5], "strides": [2, 2], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "elu", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_avg", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Conv2D", "config": {"name": "conv2d_4", "trainable": true, "dtype": "float32", "filters": 64, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "elu", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_avg", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Dropout", "config": {"name": "dropout_1", "trainable": true, "dtype": "float32", "rate": 0.2, "noise_shape": null, "seed": null}}, {"class_name": "Conv2D", "config": {"name": "conv2d_5", "trainable": true, "dtype": "float32", "filters": 64, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "elu", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_avg", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Flatten", "config": {"name": "flatten_1", "trainable": true, "dtype": "float32", "data_format": "channels_last"}}, {"class_name": "Dropout", "config": {"name": "dropout_2", "trainable": true, "dtype": "float32", "rate": 0.2, "noise_shape": null, "seed": null}}, {"class_name": "Dense", "config": {"name": "dense_1", "trainable": true, "dtype": "float32", "units": 100, "activation": "elu", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_avg", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regular ...

# %%
import pprint
import json

# %%
pp = pprint.PrettyPrinter()
pp.pprint(json.loads(to_json))
# Out:
# {'backend': 'tensorflow',
#  'class_name': 'Sequential',
#  'config': {'build_input_shape': [None, 66, 200, 3],
#             'layers': [{'class_name': 'Conv2D',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'batch_input_shape': [None, 66, 200, 3],
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 24,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [5, 5],
#                                    'name': 'conv2d_1',
#                                    'padding': 'valid',
#                                    'strides': [2, 2],
#                                    'trainable': True,
#                                    'use_bias': True}},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 36,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [5, 5],
#                                    'name': 'conv2d_2',
#                                    'padding': 'valid',
#                                    'strides': [2, 2],
#                                    'trainable': True,
#                                    'use_bias': True}},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 48,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [5, 5],
#                                    'name': 'conv2d_3',
#                                    'padding': 'valid',
#                                    'strides': [2, 2],
#                                    'trainable': True,
#                                    'use_bias': True}},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv2d_4',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True}},
#                        {'class_name': 'Dropout',
#                         'config': {'dtype': 'float32',
#                                    'name': 'dropout_1',
#                                    'noise_shape': None,
#                                    'rate': 0.2,
#                                    'seed': None,
#                                    'trainable': True}},
#                        {'class_name': 'Conv2D',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'data_format': 'channels_last',
#                                    'dilation_rate': [1, 1],
#                                    'dtype': 'float32',
#                                    'filters': 64,
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'kernel_size': [3, 3],
#                                    'name': 'conv2d_5',
#                                    'padding': 'valid',
#                                    'strides': [1, 1],
#                                    'trainable': True,
#                                    'use_bias': True}},
#                        {'class_name': 'Flatten',
#                         'config': {'data_format': 'channels_last',
#                                    'dtype': 'float32',
#                                    'name': 'flatten_1',
#                                    'trainable': True}},
#                        {'class_name': 'Dropout',
#                         'config': {'dtype': 'float32',
#                                    'name': 'dropout_2',
#                                    'noise_shape': None,
#                                    'rate': 0.2,
#                                    'seed': None,
#                                    'trainable': True}},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_1',
#                                    'trainable': True,
#                                    'units': 100,
#                                    'use_bias': True}},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_2',
#                                    'trainable': True,
#                                    'units': 50,
#                                    'use_bias': True}},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'elu',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_3',
#                                    'trainable': True,
#                                    'units': 10,
#                                    'use_bias': True}},
#                        {'class_name': 'Dense',
#                         'config': {'activation': 'linear',
#                                    'activity_regularizer': None,
#                                    'bias_constraint': None,
#                                    'bias_initializer': {'class_name': 'Zeros',
#                                                         'config': {}},
#                                    'bias_regularizer': None,
#                                    'dtype': 'float32',
#                                    'kernel_constraint': None,
#                                    'kernel_initializer': {'class_name': 'VarianceScaling',
#                                                           'config': {'distribution': 'uniform',
#                                                                      'mode': 'fan_avg',
#                                                                      'scale': 1.0,
#                                                                      'seed': None}},
#                                    'kernel_regularizer': None,
#                                    'name': 'dense_4',
#                                    'trainable': True,
#                                    'units': 1,
#                                    'use_bias': True}}],
#             'name': 'Nvidia_Model'},
#  'keras_version': '2.3.0-tf'}
